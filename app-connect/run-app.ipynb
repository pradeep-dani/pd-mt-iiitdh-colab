# %%
from kiteconnect import KiteConnect

# Step 1: Initialize KiteConnect with your API key
api_key = "j6o2ksryh5hoxkxx"
api_secret = "a7580bsq05hpj4dde6wkf9pew6995wsb"
kite = KiteConnect(api_key=api_key)

# Step 2: Get login URL and authenticate manually
print("Login URL:", kite.login_url())
# Out:
# Login URL: https://kite.zerodha.com/connect/login?api_key=j6o2ksryh5hoxkxx&v=3

# %%
# Step 3: After login, get the request token from the redirected URL
# Replace this with the actual token you get after login
request_token = "kbC2SHtH0Cn53u60y8Cjzrl98J3gOBnf"

# Step 4: Generate session and set access token
data = kite.generate_session(request_token=request_token, api_secret=api_secret)
kite.set_access_token(data["access_token"])

# %%
# Step 5: Fetch user profile
profile = kite.profile()
print("User Profile:", profile)
# Out:
# User Profile: {'user_id': 'RP1458', 'user_type': 'individual/ind_with_nom', 'email': 'pradeep.jdani@gmail.com', 'user_name': 'Pradeep Kumar', 'user_shortname': 'Pradeep', 'broker': 'ZERODHA', 'exchanges': ['NSE', 'BSE', 'MF'], 'products': ['CNC', 'NRML', 'MIS', 'BO', 'CO'], 'order_types': ['MARKET', 'LIMIT', 'SL', 'SL-M'], 'avatar_url': 'https://s3.ap-south-1.amazonaws.com/zerodha-kite-blobs/avatars/KFVFUF1eZT7Hz2hcqoJjkTvyRmzNQZUd.png', 'meta': {'demat_consent': 'physical'}}

# %%
import pandas as pd

df1 = pd.DataFrame( kite.holdings() )
print(df1.describe())
# Out:
#        instrument_token  price   quantity  used_quantity  t1_quantity  \
# count      3.400000e+01   34.0  34.000000      34.000000         34.0
# mean       9.239966e+07    0.0  20.058824       2.088235          0.0
# std        6.798771e+07    0.0  16.902467       8.486594          0.0
# min        4.249610e+05    0.0   0.000000       0.000000          0.0
# 25%        4.881217e+06    0.0   7.250000       0.000000          0.0
# 50%        1.281315e+08    0.0  18.000000       0.000000          0.0
# 75%        1.392701e+08    0.0  27.750000       0.000000          0.0
# max        1.943916e+08    0.0  69.000000      37.000000          0.0
#
#        realised_quantity  authorised_quantity  opening_quantity  \
# count          34.000000                 34.0         34.000000
# mean           20.058824                  0.0         22.147059
# std            16.902467                  0.0         16.474282
# min             0.000000                  0.0          1.000000
# 25%             7.250000                  0.0          9.000000
# 50%            18.000000                  0.0         19.000000
# 75%            27.750000                  0.0         33.000000
# max            69.000000                  0.0         69.000000
#
#        short_quantity  collateral_quantity  average_price   last_price  \
# count            34.0                 34.0      34.000000    34.000000
# mean              0.0                  0.0    1294.217721  1726.629412
# std               0.0                  0.0    1224.324616  1730.673614
# min               0.0                  0.0     218.842028   205.970000
# 25%               0.0                  0.0     515.555304   557.900000
# 50%               0.0                  0.0     757.275000  1062.325000
# 75%               0.0                  0.0    1481.320865  1954.600000
# max               0.0                  0.0    5361.500000  6804.950000
#
#        close_price           pnl  day_change  day_change_percentage
# count    34.000000     34.000000   34.000000              34.000000
# mean   1718.377647   6601.573423    8.251765               0.164953
# std    1716.668356  12795.536365   27.485601               1.503480
# min     207.910000  -7099.949988  -68.250000              -6.320030
# 25%     558.037500   -378.773974   -1.480000              -0.116746
# 50%    1074.750000    954.239724    1.290000               0.245020
# 75%    1941.350000   6679.850000   15.500000               0.922754
# max    6771.800000  49170.150000   95.950000               2.731242

# %%
df2 = pd.DataFrame( kite.mf_holdings() )
print(df2.describe())
# Out:
#         last_price      quantity   pnl  xirr  average_price  pledged_quantity  \
# count    24.000000     24.000000  24.0  24.0      24.000000              24.0
# mean    206.749613   5223.835750   0.0   0.0     170.536557               0.0
# std     453.358762   8429.875003   0.0   0.0     443.624765               0.0
# min      10.787500     36.569000   0.0   0.0      10.790682               0.0
# 25%      32.643750    398.347000   0.0   0.0      25.102095               0.0
# 50%      64.366500   1855.330500   0.0   0.0      46.137299               0.0
# 75%     184.954000   7092.561500   0.0   0.0     110.193039               0.0
# max    2259.271000  29866.188000   0.0   0.0    2216.149318               0.0
#
#        las_quantity
# count          24.0
# mean            0.0
# std             0.0
# min             0.0
# 25%             0.0
# 50%             0.0
# 75%             0.0
# max             0.0
